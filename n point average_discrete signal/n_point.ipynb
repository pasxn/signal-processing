# %%
import numpy as np
import pandas as pd
import time
from matplotlib import pyplot as plt
from alpha_vantage.timeseries import TimeSeries

# %%
api_key = '09484ac3f9mshdfe3a87a7db3584p1ff67djsne95a80e8e075'

ts = TimeSeries(key=api_key, output_format='pandas')
data, meta_data = ts.get_intraday(symbol='TSLA', interval='1min', outputsize='full')
data = data.iloc[::-1]
close = np.array(data['4. close'])
close = np.floor(close)
close = close[0:500]

# %%
plt.plot(close[6:])
plt.show()

# %%
six_point = list()

for i in range(6, len(close)):
    tmp = ( close[i]+close[i-1]+close[i-2]+close[i-3]+close[i-4]+close[i-5] )/6
    six_point.append(tmp)
    
six_point = np.floor( np.array(six_point) )

# %%
plt.plot(six_point)
plt.show()

# %%
plt.plot(close)
plt.plot(six_point)
plt.show()
